# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
print(df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area, df.price, color = 'red', marker = "+")
plt.xlabel("area")
plt.ylabel("price")
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
d = pd.read_csv("areas.csv")

d.head(3)
# Out:
#    area
# 0  1000
# 1  2300
# 2  2600

# %%
p = reg.predict(d)

print(p)
# Out:
# [316404.10958904 492928.08219178 533664.38356164 655873.28767123
#  740061.64383562 799808.21917808 903142.6369863  650441.78082192
#  899069.00684932]

# %%
d["prices"] = p
d
# Out:
#    area         prices
# 0  1000  316404.109589
# 1  2300  492928.082192
# 2  2600  533664.383562
# 3  3500  655873.287671
# 4  4120  740061.643836
# 5  4560  799808.219178
# 6  5321  903142.636986
# 7  3460  650441.780822
# 8  5291  899069.006849

# %%
d.to_csv("prediction.csv",index = False)

# %%
plt.scatter(df.area, df.price, color = 'red', marker = "+")
plt.xlabel("areas")
plt.ylabel("prices")
plt.plot(df.area, reg.predict(df[['area']]), color = "blue")
